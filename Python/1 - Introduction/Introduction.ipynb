# %% [markdown]
# Python is a general-purpose, dynamically typed, high-level, interpreted, garbage-collected, and object-oriented programming language that supports procedural, object-oriented, and functional programming.

# %% [markdown]
# Python Scripts: In script mode the code is written in a .py file and then executed from the command prompt.

# %%
# Multi-line Statements
a = 10
b = 20

total_cost: float = (a * 100 \
    + b * 100) \
    / (a + b)

print(f"Total Cost: {total_cost}")
# Out:
# Total Cost: 100.0

# %%
# Demonstrating the print function's parameters:
    # 'sep' parameter specifies the separator between the printed values
    # 'end' parameter specifies what to print at the end of the statement

print("Hello Python", "Hello C++", sep=" <seperator> ", end="\n")
print("Second Line")
# Out:
# Hello Python <seperator> Hello C++
# Second Line

# %%
# Everything in Python is an object
a = 10  # an integer object
a = 5.875685  # reassigns 'a' to a float object
print(type(a))  # prints the type of 'a', which is now <class 'float'>

b = None  # 'None' is a special object representing the absence of value, of type 'NoneType'
print("The type of b is : ", type(b))  # prints the type of 'b', which is <class 'NoneType'>

print(type('python')) # prints the type of the string literal, which is <class 'str'>
# Out:
# <class 'float'>
# The type of b is :  <class 'NoneType'>
# <class 'str'>

# %% [markdown]
# [https://www.tpointtech.com/python-variables][Object Reference]
